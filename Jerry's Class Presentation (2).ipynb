# %% [markdown]
# **PRESENTATION ON DATA STRUCTURES**
#   #BOOLEANS BY jerrysolomons

# %%
# Booleans are binary variables that have one of the two possible values,0 or 1 and true or false
# Mostly occur in the comparison of two values giving a boolean answer
# Example

print (20>15)
print (40<30)
# Out:
# True
# False

# %% [markdown]
# some operators in **python**

# %%
#== is a comparison operator that gives a false,true or an error
#bool() allows one to evaluate a value returning a 'true' or 'false' answer

# %%
# Example
# Running a condition in an if statement the answer is a true or false
# when evaluating a string or a number

x = 'hallo'
y = 15

print (bool(x))
print(bool(y))
# Out:
# True
# True

# %%
# any string is true,except empty strings
#any number is true except 0
#any list ,tuple and dictionary are true, except empty ones

#Example
bool(['a','b','c'])
bool([1,2,3])
bool(0)
bool(['oranges','bananas','apple'])
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(None)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
# Not many values evaluate to false except (),{},[],'''',0,and the value none
#example
bool({})
# Out:
# False

# %%
bool([])
# Out:
# False

# %%
bool('')
# Out:
# False

# %% [markdown]
# NB: the isinstace() is usedin python to assertain a particular type of data

# %%
x= 400.35

print(isinstance(x,int))
# Out:
# False

# %%
#simply means that the number 400.35 is not an integer

# %% [markdown]
# MY DAY TO DAY DATA AT WORK **PLACE**

# %%
#Quantitative data      #-Covid-19 reported by the Ministry of health in every 24 hours
                        #- Fines collected by various base commands in Nairobi
                        #- Number of crimes committed within the country for the last 24 hours
                        #-Injury to Police officers for the 24 hours

 Currently we are analysing a survey conducted by the Directorate of training on officers competency on ICT in line with the implementation of the Digital OB
